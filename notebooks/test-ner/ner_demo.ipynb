# %% [markdown]
# # NER Class Demo - Sync and Async Usage
#
# This notebook demonstrates how to use the enhanced NER class that supports both synchronous and asynchronous operations for named entity recognition.

# %%
# %load_ext autoreload
# %autoreload 2

from explain.enhanced_chat.ec_ner import NER

# %% [markdown]
# ## Initialize NER Instance
#
# This will prompt for authentication if you haven't authenticated recently.
#
# ### Synchronous Usage
#
# Use the NER class synchronously

# %%
ner = NER()
# Out:
# 2025-08-21 16:07:05.162 | INFO     | explain.enhanced_chat._access_token:get_access_token:31 - Starting OAuth device code flow
# 2025-08-21 16:07:05.886 | INFO     | explain.enhanced_chat._access_token:get_access_token:48 - Please open the following URL in your browser:
# 2025-08-21 16:07:05.887 | INFO     | explain.enhanced_chat._access_token:get_access_token:49 -
# https://okta.recursionpharma.com/activate?user_code=BQHMRRNQ
#
# 2025-08-21 16:07:05.887 | INFO     | explain.enhanced_chat._access_token:get_access_token:50 - Or go to: https://okta.recursionpharma.com/activate
# 2025-08-21 16:07:05.887 | INFO     | explain.enhanced_chat._access_token:get_access_token:51 - And enter code: BQHMRRNQ
# 2025-08-21 16:07:05.887 | INFO     | explain.enhanced_chat._access_token:get_access_token:63 - Auto-open disabled - please open the URL manually
# 2025-08-21 16:07:05.888 | INFO     | explain.enhanced_chat._access_token:get_access_token:65 - Waiting for authentication...
# 2025-08-21 16:07:05.888 | INFO     | explain.enhanced_chat._access_token:get_access_token:72 - Polling attempt 1
# 2025-08-21 16:07:11.274 | INFO     | explain.enhanced_chat._access_token:get_access_token:72 - Polling attempt 2
# 2025-08-21 16:07:16.626 | INFO     | explain.enhanced_chat._access_token:get_access_token:72 - Polling attempt 3
# 2025-08-21 16:07:17.176 | SUCCESS  | explain.enhanced_chat._access_token:get_access_token:93 - Authentication successful!

# %%
# Test synchronous calls
test_texts = [
    "compound_CHEMBL1237044 doxorubicin and magnesium SMILES, Chemical is a suppressing drug",
    "The gene TP53 encodes p53 protein and is inhibited by ifosfamide and Cc1ccc(cc1Nc2nccc(n2)c3cccnc3)NC(=O)c4ccc(cc4)CN5CCN(CC5)C",
    "EGFR mutations are common in lung cancer and insulin is a drug that benzaldehyde inhibits it C7H6O HUMNYLRZRPPJDN-UHFFFAOYSA-N",
    "Cowden Syndrome is a disease"
]

for i, text in enumerate(test_texts, 1):
    print(f"\n{i}. Input: '{text}'")

    # Method 1: Using __call__ (shorthand)
    result = await ner.averify(text, options=["DISEASE", "GENE"])

    # Method 2: Using verify method explicitly
    # result = ner.verify(text)

    print(f"   Result: {result}")
# Out:
# 1. Input: 'compound_CHEMBL1237044 doxorubicin and magnesium SMILES, Chemical is a suppressing drug'
#    Result: []
#
# 2. Input: 'The gene TP53 encodes p53 protein and is inhibited by ifosfamide and Cc1ccc(cc1Nc2nccc(n2)c3cccnc3)NC(=O)c4ccc(cc4)CN5CCN(CC5)C'
#    Result: [Span(begin=19, end=23, id='ENSEMBL:ENSG00000141510', type_=<EntityType.GENE: 'GENE'>, additional_properties={}), Span(begin=32, end=35, id='ENSEMBL:ENSG00000141510', type_=<EntityType.GENE: 'GENE'>, additional_properties={})]
#
# 3. Input: 'EGFR mutations are common in lung cancer and insulin is a drug that benzaldehyde inhibits it C7H6O HUMNYLRZRPPJDN-UHFFFAOYSA-N'
#    Result: [Span(begin=10, end=14, id='ENSEMBL:ENSG00000146648', type_=<EntityType.GENE: 'GENE'>, additional_properties={}), Span(begin=39, end=50, id='http://id.nlm.nih.gov/mesh/D008175', type_=<EntityType.DISEASE: 'DISEASE'>, additional_properties={})]
#
# 4. Input: 'Cowden Syndrome is a disease'
#    Result: [Span(begin=10, end=25, id='http://id.nlm.nih.gov/mesh/D006223', type_=<EntityType.DISEASE: 'DISEASE'>, additional_properties={})]
