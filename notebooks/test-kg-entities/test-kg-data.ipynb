# %%
# %load_ext autoreload
# %autoreload 2

from explain.utils.kg_client import KGClient

# %%
client = KGClient()

await client.get_compound_info("CHEMBL25")
# Out:
# {'id': 'CHEMBL25',
#  'smiles': 'CC(=O)Oc1ccccc1C(=O)O',
#  'name': 'ASPIRIN',
#  'synonyms': ['2-Acetoxy-benzoic acid (aspirin)',
#   'Acetylsalicyclic acid',
#   'Disprin cv',
#   'SID144209315',
#   'SID17389202',
#   'NSC-406186',
#   'acetylsalicylic acid',
#   '(aspirin)2-Acetoxy-benzoic acid',
#   'Benzoic acid, 2-(acetyloxy)-',
#   'SID174007205',
#   'Asparin',
#   'Vazalore',
#   'Measurin',
#   'Acetyl salicylate',
#   'o-acetylsalicylic acid',
#   'Acetylsalicylic Acid',
#   'SID90340586',
#   'Acetylsalic acid',
#   'SID85230910',
#   'Nu-seals cardio 75',
#   'Postmi 300',
#   'Enprin',
#   'NSC-27223',
#   'Anadin all night',
#   'Asprin',
#   'Acetylsalicylic acid',
#   '2-(acetyloxy)benzoic acid',
#   'Paynocil',
#   'ASPIRINE',
#   'Platet 300',
#   'Alka rapid',
#   'Acetylsalicylic acid; Aspirin',
#   'SID26747283',
#   'Acetylsalicylicum acidum',
#   'Gencardia',
#   'Aspirin',
#   'Durlaza',
#   '2-acetoxybenzoate',
#   'ASPIRIN',
#   'Micropirin ec',
# ...

# %%
await client.get_gene_info("ENSG00000139618")
# Out:
# {'id': 'ENSG00000139618',
#  'symbol': 'BRCA2',
#  'name': 'BRCA2 DNA repair associated',
#  'entrez_id': '675',
#  'refseq_id': 'NM_000059',
#  'uniprot_id': 'P51587',
#  'hgnc_id': '1101',
#  'synonyms': ['XRCC11',
#   'FANCD',
#   'breast cancer 2',
#   'FAD1',
#   'BRCC2',
#   'FANCD1',
#   'FACD',
#   'Fanconi anemia, complementation group D1',
#   'breast cancer 2, early onset',
#   'FAD',
#   'BRCA1/BRCA2-containing complex, subunit 2']}

# %%
await client.get_disease_info("MESH:D003324")
# Out:
# {'id': 'MESH:D003324',
#  'mondo_id': 'MONDO:0005010',
#  'mesh_id': 'D003324',
#  'umls_id': 'C1956346',
#  'ncit_id': 'C26732',
#  'orphanet_id': '',
#  'name': 'coronary artery disorder',
#  'definition': 'Narrowing of the coronary arteries due to fatty deposits inside the arterial walls. The diagnostic criteria may include documented history of any of the following: documented coronary artery stenosis greater than or equal to 50% (by cardiac catheterization or other modality of direct imaging of the coronary arteries); previous coronary artery bypass surgery (CABG); previous percutaneous coronary intervention (PCI); previous myocardial infarction. (ACC)',
#  'synonyms': ['CAD',
#   'CHD',
#   'CHD (coronary heart disease)',
#   'coronary artery disease',
#   'coronary artery disease or disorder',
#   'coronary disease',
#   'coronary heart disease',
#   'disease of coronary artery',
#   'disease or disorder of coronary artery',
#   'disorder of coronary artery',
# ...

# %%
await client.get_disease_info("MONDO:0005010")
# Out:
# {'id': 'MONDO:0005010',
#  'mondo_id': 'MONDO:0005010',
#  'mesh_id': 'D003324',
#  'umls_id': 'C1956346',
#  'ncit_id': 'C26732',
#  'orphanet_id': '',
#  'name': 'coronary artery disorder',
#  'definition': 'Narrowing of the coronary arteries due to fatty deposits inside the arterial walls. The diagnostic criteria may include documented history of any of the following: documented coronary artery stenosis greater than or equal to 50% (by cardiac catheterization or other modality of direct imaging of the coronary arteries); previous coronary artery bypass surgery (CABG); previous percutaneous coronary intervention (PCI); previous myocardial infarction. (ACC)',
#  'synonyms': ['CAD',
#   'CHD',
#   'CHD (coronary heart disease)',
#   'coronary artery disease',
#   'coronary artery disease or disorder',
#   'coronary disease',
#   'coronary heart disease',
#   'disease of coronary artery',
#   'disease or disorder of coronary artery',
#   'disorder of coronary artery',
# ...

# %%
await client.get_cellular_context_info("293T")
# Out:
# {'results': [{'id': 'CVCL_0063',
#    'name': 'HEK293T',
#    'cell_type': 'CulturedCell',
# ...
